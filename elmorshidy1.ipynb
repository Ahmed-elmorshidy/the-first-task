# %% [markdown]
# ###  Using list comprehension ,list related functions or otherwise, create following list:
#
#    [[1, 2, 3, 4, 5, 6, 7], [1, 4, 9, 16, 25, 36, 49], [1, 8, 27, 64, 125, 216,343]]

# %%
oddlist= [oddnum for oddnum in range(1,15) if oddnum%2 !=0]
list1 = [[numbers1 for numbers1 in range(1,8)],#[numbers2 if numbers2 == numbers2+oddlist else print('') for numbers2 in range (1,50) ],
         [numbers3**3 for numbers3 in range(1,8)]]
list1

# %% [markdown]
# **in upper cell in comment idk what the error or how to add list to other in for loop**

# %%
oddlist
# Out:
# [1, 3, 5, 7, 9, 11, 13]

# %% [markdown]
# ### Use List comprehension to create a list of all numbers between 1 and 50 that are divisible by 3.

# %%
list3 = [allnum for allnum  in range (1,51) if allnum %3 == 0]
list3
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48]

# %% [markdown]
# ###  Use List Comprehension to create a list of the first letters of ever-y word in the string below:
#
# st = 'Create a list of the first letters of every word in this string'

# %% [markdown]
# ### Write a program to extract phone numbers for each location
#
# - Consider this dictionary of addresses :
#
# {“home” : [“Hyderabad”,“Lingampally”,“Ph:1234567890”],
#
# “office”:[“Maharashtra”,“Mumbai”,“Ghatkopar”,“Ph : 5432167809”,“Pin :400043”],
#
# “OOI” : [“Singapore”,“Ph : 09876345”]}

# %%
dic = {home : ['Hyderabad','Lingampally',Ph : 1234567890],

'office':['Maharashtra','Mumbai','Ghatkopar',Ph : 5432167809,Pin :400043],

'OOI' : ['Singapore','Ph' : 09876345]}
extract = [ pnumbers for pnumbers in dic{} if 'ph' in pnumbers ]
extract
# Out:
#   File "<ipython-input-48-353873933edf>", line 1
#     dic = {home : ['Hyderabad','Lingampally',Ph : 1234567890],
#                                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Reverse the string 'Mega' using slicing

# %%
str1="Mega"
str1[::-1]
# Out:
# 'ageM'

# %% [markdown]
# ###  in the string below if the **length of a word** is even print "even!"
# string = 'Print every word in this sentence that has an even number of letters'

# %%
string = "Print every word in this sentence that has an even number of letters"
string.split()
string2 = [x   for x in string.split() if len(x)%2 ==0]

# %% [markdown]
# ## Create a tuple of 5 elements and then multiply each element of the tuple by 2 & save the results in a list

# %%
l1 = []
for x in range(1,6):
    l1.append(x*2)
l1
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# ### Solve these problems :-
#
# *  https://www.hackerrank.com/challenges/python-string-split-and-join/problem
# *  https://www.hackerrank.com/challenges/write-a-function/problem
# *  https://www.hackerrank.com/challenges/py-if-else/problem

# %% [markdown]
# # problem 1

# %%
st2="My Name Is Ahmed Elmorshidy"
st2=st2.split(" ")
st2="-".join(st2)
print(st2)
# Out:
# My-Name-Is-Ahmed-Elmorshidy

# %% [markdown]
# # problem 2

# %%
def is_leap(year):
    return year % 4 == 0 and (year % 400 == 0 or year % 100 != 0)
year = int(input('enter the year please : '))
print(is_leap(year))

# %% [markdown]
# # problem 3

# %%
num = int(input('enter a number please here : '))

if num %2 !=0 :
        print ('weird')
elif num %2 == 0 and num in range(2,6) :
        print ('not weird')
elif num %2 ==0 and num in range (6,20) : 
        print ("weird")
elif num %2 ==0 and 20 <= num <= 100 :
        print ('not weird')

# %% [markdown]
# ###   counts how many times the letter “r” appears in the phrase bellow and then print it out .
#
# phrase = "Is it better to have an outlier in your own data ? of course not, to be content with reality; if it's not so bright as dreams,create your fav routine  "

# %%
phrase = "Is it better to have an outlier in your own data ? of course not, to be content with reality; if it's not so bright as dreams,create your fav routine "
str2 = [ x for x in phrase if 'r' in x]
print(len(str2))
# Out:
# 10
